# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
con = sqlite3.connect("Pitchfork.sqlite")
df_pitchfork = pd.read_sql_query("SELECT * FROM reviews", con)

# Verify that result of SQL query is stored in the dataframe
print(df_pitchfork.head())

con.close()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22661           first songs  kleenex, liliput
# 4     22725             new start              taso
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
# 4  http://pitchfork.com/reviews/albums/22725-new-...    8.1               0
#
#            author               author_type    pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor  2017-01-08            6        8
# 1        zoe camp               contributor  2017-01-07            5        7
# 2  david glickman               contributor  2017-01-07            5        7
# 3      jenn pelly  associate reviews editor  2017-01-06            4        6
# 4    kevin lozano        tracks coordinator  2017-01-06            4        6
#
#    pub_month  pub_year
# 0          1      2017
# 1          1      2017
# 2          1      2017
# 3          1      2017
# 4          1      2017

# %%
# def strip_whitespace(item):
#     return item.strip()
df_pitchfork['author'] = df_pitchfork['author'].apply(lambda d:d.strip())

# %%
df_pitchfork.head(30)
# Out:
#     reviewid                                              title  \
# 0      22703                                          mezzanine
# 1      22721                                       prelapsarian
# 2      22659                               all of them naturals
# 3      22661                                        first songs
# 4      22725                                          new start
# 5      22722      insecure (music from the hbo original series)
# 6      22704                            stillness in wonderland
# 7      22694                                           tehillim
# 8      22714                                         reflection
# 9      22724                       filthy america its beautiful
# 10     22715                              clear sounds/perfetta
# 11     22745                                   run the jewels 3
# 12     22700                                              nadir
# 13     22720                                      december 99th
# 14     22699                                   don't smoke rock
# 15     22665  punk45: les punks: the french connection (the ...
# 16     22666                                    brnshj (puncak)
# 17     22719                           merry christmas lil mama
# 18     22667                                    ///// effectual
# 19     22691                                  love you to death
# 20     22702                                what graceless dawn
# 21     22718                           not the actual events ep
# 22     22706                                       holy science
# 23     22695                             early tapes, 1996-1998
# 24     22713                                   the wasp factory
# 25     22705                             a very kacey christmas
# 26     22532                                          turn into
# 27     22701      traditional music of notional species vol. ii
# 28     22707             swiss radio days vol. 41 - zurich 1961
# 29     22708                                 do what thou wilt.
#
#                         artist  \
# 0               massive attack
# 1                     krallice
# 2                 uranium club
# 3             kleenex, liliput
# 4                         taso
# 5              various artists
# 6                  little simz
# 7                   yotam avni
# 8                    brian eno
# 9                      the lox
# 10               harry bertoia
# 11              run the jewels
# 12              steven warwick
# 13                  yasiin bey
# 14        smoke dza, pete rock
# 15             various artists
# 16                     senyawa
# 17  chance the rapper, jeremih
# 18             jamire williams
# 19                   the-dream
# 20              worm ouroboros
# 21             nine inch nails
# 22                  elder ones
# 23             the microphones
# 24                   ben frost
# 25             kacey musgraves
# 17       sheldon pearce    associate staff writer  2016-12-30            4
# 18      benjamin scheim               contributor  2016-12-30            4
# 19    rebecca haithcoat               contributor  2016-12-29            3
# 20         sam sodomsky    associate staff writer  2016-12-29            3
# 21      benjamin scheim               contributor  2016-12-28            2
# 22    seth colter walls               contributor  2016-12-28            2
# 23      benjamin scheim               contributor  2016-12-27            1
# 24           brian howe               contributor  2016-12-27            1
# 25           marc hogan       senior staff writer  2016-12-23            4
# 26       quinn moreland          assistant editor  2016-12-23            4
# 27            andy beta               contributor  2016-12-23            4
# 28    seth colter-walls               contributor  2016-12-22            3
# 29       sheldon pearce    associate staff writer  2016-12-22            3
#
#     pub_day  pub_month  pub_year
# 0         8          1      2017
# 1         7          1      2017
# 2         7          1      2017
# 3         6          1      2017
# 4         6          1      2017
# 5         5          1      2017
# 6         5          1      2017
# 7         5          1      2017
# 8         4          1      2017
# 9         4          1      2017
# 10        4          1      2017
# 11        3          1      2017
# 12        3          1      2017
# 13        2          1      2017
# 14        2          1      2017
# 15        2          1      2017
# 16        2          1      2017
# 17       30         12      2016
# 18       30         12      2016
# 19       29         12      2016
# 20       29         12      2016
# 21       28         12      2016
# 22       28         12      2016
# 23       27         12      2016
# 24       27         12      2016
# 25       23         12      2016
# 26       23         12      2016
# 27       23         12      2016
# 28       22         12      2016
# 29       22         12      2016

# %%
unique_authors = df_pitchfork['author'].unique()
print(len(unique_authors), ' ', unique_authors)
# Out:
# 423   ['nate patrin' 'zoe camp' 'david glickman' 'jenn pelly' 'kevin lozano'
#  'vanessa okoth-obbo' 'katherine st. asaph' 'andy beta' 'ian cohen'
#  'marc masters' 'sheldon pearce' 'thea ballard' 'marcus j. moore'
#  'dean van nguyen' 'louis pattison' 'philip sherburne' 'benjamin scheim'
#  'rebecca haithcoat' 'sam sodomsky' 'seth colter walls' 'brian howe'
#  'marc hogan' 'quinn moreland' 'seth colter-walls' 'savy reyes-kulkarni'
#  'renato pagnani' 'matthew strauss' 'david turner' 'matthew ramirez'
#  'jesse jarnow' 'andrew gaerig' 'paul a. thompson' 'nathan reese'
#  'ryan dombal' 'jayson greene' 'cameron cook' 'saby reyes-kulkarni'
#  'mehan jayasuriya' 'ben scheim' 'stuart berman' 'israel daramola'
#  'evan rytlewski' 'daniel martin-mccormick' 'jay balfour' 'drew gaerig'
#  'mark richardson' 'paul thompson' 'edwin "stats" houghton' 'laura snapes'
#  'eric harvey' 'brad nelson' 'jonathan bernstein' 'caryn rose'
#  'jes skolnik' 'miles raymer' 'nina mashurova' 'dorian lynskey'
#  'jonathan patrick' 'kris ex' 'mike powell' 'brian burlage'
#  'john s.w. macdonald' 'saby reyes kulkarni' 'raymond cummings'
#  'evan minsker' 'marcus k. dowling' 'ryan leas' 'simon goddard'
#  'matthew grosinger' 'edwin stats houghton' 'stephen thomas erlewine'
#  'matthew ismael ruiz' 'michael j. agovino' 'simon reynolds'
#  "andy o'connor" 'douglas wolk' 'alexander iadarola' 'minna zhou'
#  'colin joyce' 'amanda petrusich' 'stacey anderson' 'stephen m. deusner'
#  'claire lobenfeld' 'jillian mapes' 'jonah bromwich' 'winston cook-wilson'
#  'julianne escobedo shepherd' 'jason heller' 'steven hyden'
#  'daphne a. brooks' 'piotr orlov' 'chris randle' 'erin macleod'
#  'grayson haver currin' 'judy berman' 'rob mitchum' 'pat healy'
#  'patrick st. michel' 'alan light' 'matthew schnipper' 'jazz monroe'
#  'jeff weiss' 'jeremy gordon' 'carvell wallace' 'david drake'
#  'kathy iandoli' 'andrew nosnitsky' 'brendan mattox' 'abigail covington'
#  'allison hussey' 'rohan samarth' 't. cole rachel' 'jia tolentino'
#  'barry walters' 'patric fallon' 'aaron leitko' 'brandon stosuy'
#  'lindsay hood' 'nelson george' 'maura johnston' 'timmhotep aku'
#  'corban goble' 'ron hart' 'britt julious' 'robert ham' 'craig jenkins'
#  'maria sherman' 'sean t. collins' 'andy emitt' 'sam lefebvre'
#  'ilana kaplan' 'estelle tang' 'ernest wilkins' 'nina corcoran'
#  'julian kimble' 'sarah sahim' 'sam hockley-smith' 'mosi reeves'
#  'hazel cills' 'eric torres' 'christine kakaire' 'molly beauchemin'
#  'tom ewing' 'j. edward keyes' 'meaghan garvey' 'anupa mistry'
#  'max mertens' 'jessica hopper' 'leor galil' 'tayler montague'
#  'puja patel' 'abby garnett' 'felipe delerme' 'joel oliphint'
#  'jakob dorof' 'sasha geffen' 'corbin reiff' 'zach kelly' 'nick neyland'
#  'john everhart' 'andrew ryce' 'abigail garnett' 'jonathan zwickel'
#  'ned raggett' 'tess duncan' 'safy-hallan farah' "andy o' connor"
#  'maud deitch' 'hannah giorgis' 'clayton purdom' 'tim finney'
#  'b. david zarley' 'matthew murphy' 'jonathan k. dick' 'jeremy d. larson'
#  'jamieson cox' 'liz pelly' 'joe tangari' 'rawiya kameir' 'mark pytlik'
#  'jordan sargent' 'lawrence burney' 'melody lau' 'jake cleland'
#  'martin douglas' 'devon maloney' 'vish khanna' 'larry fitzmaurice'
#  'kim kelly' 'carrie battan' 'matt lemay' 'stephen deusner' 'paula mejia'
#  'lindsay zoladz' 'harley brown' 'kyle kramer' 'jessica suarez'
#  'gabriel szatan' 'colin st. john' 'hank shteamer' 'grayson currin'
#  'angus finlayson' 'ruth saxelby' 'jeremy larson' 'patrick bowman'
#  'mike madden' 'rachael maddux' 'lisa blanning' 'katherine st asaph'
#  'hari ashurst' 'jess harvell' 'emilie friedlander' 'joe colly'
#  'matthew perpetua' 'josh love' 'eric grandy' 'brandon soderberg'
#  'david raposa' 'b michael payne' 'matthew solarski' 'drew daniel'
#  'joshua love' 'rob harvilla' 'sean fennessy' 'tom breihan' 'david bevan'
#  'scott plagenhoef' 'sean fennessey' 'dominique leone' 'finn cohen'
#  'patrick sisson' 'tal rosenberg' 'andy battaglia' 'rebecca raber'
#  'amy granzin' 'joshua klein' 'liz colville' 'nitsuh abebe' 'jason crock'
#  'chris dahlen' 'mike orme' 'leonard pierce' 'jonathan garrett'
#  'stephen trouss' 'cosmo lee' 'martin clark' 'adam moerder' 'mia clarke'
#  'roque strew' 'mike mcgonigal' 'adrienne day' 'd. shawn bosler'
#  'kasia galazka' 'bob stanley' 'evan mcgarvey' 'ben westhoff'
#  'mia lily clarke' 'zach baron' 'william bowers' 'robbie mackey'
#  'sam eccleston' 'sam chennault' 'ryan schreiber' 'sara sherr'
#  'stosh "piz" piznarski' 'carl wilson' 'alex lindhart' 'dave stelfox'
#  'nick mirov' 'peter macia' 'cory d. byrom' 'john motley' 'alex linhardt'
#  'judson picco' 'rachel khong' 'ray suzuki' 'mark richard-san' 'sam ubl'
#  'chip chanko' 'cory byrom' 'will dukes' 'michael idov' 'brent s. sirota'
#  'nick sylvester' 'amy phillips' 'johnny loftus' 'austin gaines'
#  'jeff leven' 'jamin warren' 'brian howe & brandon stosuy'
#  'stephen  m. deusner' 'cameron macdonald' 'eric carr'
#  'stephen m. duesner' 'isaiah violante' 'malcolm seymour iii'
#  'david moore' 'derek miller' 'mark richard-san & ryan schreiber'
#  'liam singer' 'natalie moore' 'jason josephes' 'nathan humpal'
#  'andrew bryant' 'zach vowell' 'andrew lehman' 'j.h. tompkins'
#  'neil robertson' 'camilo arturo leslie' 'stephen may' 'catherine lewis'
#  'dan lett' 'rollie pemberton' 'james p. wisdom' 'brent dicrescenzo'
#  'mark richardson & nick sylvester' 'loren ludwig & jascha hoffman'
#  'andy beta, brandon stosuy & mark richardson' 'jedediah gilchrist'
#  'philip shelley' 'chris weber' 'christopher sebela'
#  'rollie pemberton & nick sylvester' 'christopher weber' 'jt ramsay'
#  'hartley goldstein' 'chris drabick' 'j. wasserman' 'william morris'
#  'chris dahlen, dominique leone & joe tangari' 'p.j. gallagher'
#  'dan miron' 'pj gallagher' 'jascha hoffman' 'casey rea' 'philip welsh'
#  'alan smithee' 'andy linhardt' "john o'connor" 'the pitchfork staff'
#  'noah sutcliffe'
#  'choppa moussaoui, with help from mullah omar, ethan p, and'
#  'alexander lloyd linhardt' 'craig rostron' 'nicholas b. sylvester'
#  'bob o. mcmillan' 'brad hurst' 'stephen haag' 'bill morris' 'scott hreha'
#  'mark martelli' 'dr. andy beta' 'matt kallman' 'daniel crumb'
#  'brendan reid' 'will bryant' 'oliver lache' 'brian james' 'matt stephens'
#  'matthew stephens' 'kim shannon' 'kim fing shannon' 'kyle reiter'
#  'matthew wellins' 'matt wellins' 'brad haywood' 'david m. pecoraro'
#  'paul cooper' 'jason nickey' 'chris dahlen & ryan schreiber'
#  'jesse fahnestock' 'ryan kearney' 'kevin adickes' 'christopher dare'
#  'christopher f. schiel' 'mike bernstein' 'alison fields' 'brandon wall'
#  'meg zamula' 'keith brasel' 'michael bernstein' 'ethan p.'
#  'ryan schreiber & alison fields' 'zach hooker' 'brock kappers'
#  'brad haywood & ryan schreiber' 'nathan rooney' 'john dark'
#  'luke buckman' 'daphne carr' 'andi rowlands' 'dan kilian'
#  'kristin sage rockermann' 'adam dlugacz' 'spencer owen'
#  'dan kilian & ryan schreiber' 'jonny pietin' 'richard m. juzwiak'
#  'samir khan' 'kristin sage rockermann & chip chanko' 'edward howard'
#  'd. erik kempke' 'michael sandlin' 'steven byrd' 's. murray' 'al shipley'
#  'craig griffith' 'michael wartenbe' 'andrew goldman' 'hefner macauley'
#  'pete nicholson' 'taylor m. clark' 'beatty & garrett' 'adam ohler'
#  'dan gardopee' 'shan fowler' 'jeremy schneyer' 'yancey strickler'
#  'neil lieberman' 'jared bane' 'zach hammerman' 'sarah zupko'
#  'bruce tiffee']

# %%
def levenshtein_ratio_and_distance(s, t, ratio_calc = False):
    """ levenshtein_ratio_and_distance:
        Calculates levenshtein distance between two strings.
        If ratio_calc = True, the function computes the
        levenshtein distance ratio of similarity between two strings
        For all i and j, distance[i,j] will contain the Levenshtein
        distance between the first i characters of s and the
        first j characters of t
    """
    # Initialize matrix of zeros
    rows = len(s)+1
    cols = len(t)+1
    distance = np.zeros((rows,cols),dtype = int)

    # Populate matrix of zeros with the indeces of each character of both strings
    for i in range(1, rows):
        for k in range(1,cols):
            distance[i][0] = i
            distance[0][k] = k

    # Iterate over the matrix to compute the cost of deletions,insertions and/or substitutions    
    for col in range(1, cols):
        for row in range(1, rows):
            if s[row-1] == t[col-1]:
                cost = 0 # If the characters are the same in the two strings in a given position [i,j] then the cost is 0
            else:
                # In order to align the results with those of the Python Levenshtein package, if we choose to calculate the ratio
                # the cost of a substitution is 2. If we calculate just distance, then the cost of a substitution is 1.
                if ratio_calc == True:
                    cost = 2
                else:
                    cost = 1
            distance[row][col] = min(distance[row-1][col] + 1,      # Cost of deletions
                                 distance[row][col-1] + 1,          # Cost of insertions
                                 distance[row-1][col-1] + cost)     # Cost of substitutions
    if ratio_calc == True:
        # Computation of the Levenshtein Distance Ratio
        Ratio = ((len(s)+len(t)) - distance[row][col]) / (len(s)+len(t))
        return Ratio
    else:
        # print(distance) # Uncomment if you want to see the matrix showing how the algorithm computes the cost of deletions,
        # insertions and/or substitutions
        # This is the minimum number of edits needed to convert string a to string b
        return "The strings are {} edits away".format(distance[row][col])

# %%
# authors = {}
print(unique_authors.sort())
# for author in unique_authors:
#     author = author.rstrip()
    
# unique_authors = unique_authors.unique()
# print(len(unique_authors), ' ', unique_authors)

for item in unique_authors:
    print(item)
# Out:
# None
# aaron leitko
# abby garnett
# abigail covington
# abigail garnett
# adam dlugacz
# adam moerder
# adam ohler
# adrienne day
# al shipley
# alan light
# alan smithee
# alex lindhart
# alex linhardt
# alexander iadarola
# alexander lloyd linhardt
# alison fields
# allison hussey
# amanda petrusich
# amy granzin
# amy phillips
# andi rowlands
# andrew bryant
# andrew gaerig
# andrew goldman
# andrew lehman
# andrew nosnitsky
# andrew ryce
# andy battaglia
# andy beta
# andy beta, brandon stosuy & mark richardson
# andy emitt
# andy linhardt
# andy o' connor
# andy o'connor
# angus finlayson
# anupa mistry
# austin gaines
# b michael payne
# b. david zarley
# barry walters
# beatty & garrett
# ben scheim
# ben westhoff
# benjamin scheim
# bill morris
# bob o. mcmillan
# bob stanley
# brad haywood
# brad haywood & ryan schreiber
